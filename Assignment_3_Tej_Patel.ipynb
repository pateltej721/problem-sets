# %% [markdown]
# <a href="https://colab.research.google.com/github/pateltej721/problem-sets/blob/main/Assignment_3_Tej_Patel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing housing_data.csv data set

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e8e6cd14-235e-42aa-b093-40902e25ff01" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e8e6cd14-235e-42aa-b093-40902e25ff01">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving housing_data.csv to housing_data (2).csv

# %%
import pandas as pd
import numpy as np
import plotnine as pn
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from numpy.random import default_rng

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['housing_data.csv']))

# %%
df
# Out:
#     Lot Frontage  Lot Area  Street  ...  Mo Sold  Yr Sold  SalePrice
# 0             60      6756       1  ...        9     2008      78000
# 1             80     10000       1  ...       12     2007     215000
# 2             71      9353       1  ...        7     2006     116050
# 3             57      6420       1  ...        9     2006     123500
# 4             57      9245       1  ...        2     2008     145000
# ..           ...       ...     ...  ...      ...      ...        ...
# 95            71      9187       1  ...        6     2007     134000
# 96            34      3604       1  ...        2     2008     146000
# 97           140     11080       1  ...        5     2006     148000
# 98            60      7200       1  ...        8     2007     140000
# 99            58      9487       1  ...        6     2007     187000
#
# [100 rows x 37 columns]

# %%
y = df['SalePrice']

# %%
del df['Street']

# %%
df
# Out:
#     Lot Frontage  Lot Area  Overall Qual  ...  Mo Sold  Yr Sold  SalePrice
# 0             60      6756             5  ...        9     2008      78000
# 1             80     10000             5  ...       12     2007     215000
# 2             71      9353             4  ...        7     2006     116050
# 3             57      6420             5  ...        9     2006     123500
# 4             57      9245             5  ...        2     2008     145000
# ..           ...       ...           ...  ...      ...      ...        ...
# 95            71      9187             6  ...        6     2007     134000
# 96            34      3604             7  ...        2     2008     146000
# 97           140     11080             6  ...        5     2006     148000
# 98            60      7200             5  ...        8     2007     140000
# 99            58      9487             6  ...        6     2007     187000
#
# [100 rows x 36 columns]

# %%
del df['Low Qual Fin SF']

# %%
df
# Out:
#     Lot Frontage  Lot Area  Overall Qual  ...  Mo Sold  Yr Sold  SalePrice
# 0             60      6756             5  ...        9     2008      78000
# 1             80     10000             5  ...       12     2007     215000
# 2             71      9353             4  ...        7     2006     116050
# 3             57      6420             5  ...        9     2006     123500
# 4             57      9245             5  ...        2     2008     145000
# ..           ...       ...           ...  ...      ...      ...        ...
# 95            71      9187             6  ...        6     2007     134000
# 96            34      3604             7  ...        2     2008     146000
# 97           140     11080             6  ...        5     2006     148000
# 98            60      7200             5  ...        8     2007     140000
# 99            58      9487             6  ...        6     2007     187000
#
# [100 rows x 35 columns]

# %%
del df['3Ssn Porch']

# %%
df
# Out:
#     Lot Frontage  Lot Area  Overall Qual  ...  Mo Sold  Yr Sold  SalePrice
# 0             60      6756             5  ...        9     2008      78000
# 1             80     10000             5  ...       12     2007     215000
# 2             71      9353             4  ...        7     2006     116050
# 3             57      6420             5  ...        9     2006     123500
# 4             57      9245             5  ...        2     2008     145000
# ..           ...       ...           ...  ...      ...      ...        ...
# 95            71      9187             6  ...        6     2007     134000
# 96            34      3604             7  ...        2     2008     146000
# 97           140     11080             6  ...        5     2006     148000
# 98            60      7200             5  ...        8     2007     140000
# 99            58      9487             6  ...        6     2007     187000
#
# [100 rows x 34 columns]

# %%
del df['Mo Sold']

# %%
df
# Out:
#     Lot Frontage  Lot Area  Overall Qual  ...  Misc Val  Yr Sold  SalePrice
# 0             60      6756             5  ...         0     2008      78000
# 1             80     10000             5  ...         0     2007     215000
# 2             71      9353             4  ...         0     2006     116050
# 3             57      6420             5  ...         0     2006     123500
# 4             57      9245             5  ...         0     2008     145000
# ..           ...       ...           ...  ...       ...      ...        ...
# 95            71      9187             6  ...         0     2007     134000
# 96            34      3604             7  ...         0     2008     146000
# 97           140     11080             6  ...         0     2006     148000
# 98            60      7200             5  ...         0     2007     140000
# 99            58      9487             6  ...         0     2007     187000
#
# [100 rows x 33 columns]

# %%
del df['Year Built']

# %%
df
# Out:
#     Lot Frontage  Lot Area  Overall Qual  ...  Misc Val  Yr Sold  SalePrice
# 0             60      6756             5  ...         0     2008      78000
# 1             80     10000             5  ...         0     2007     215000
# 2             71      9353             4  ...         0     2006     116050
# 3             57      6420             5  ...         0     2006     123500
# 4             57      9245             5  ...         0     2008     145000
# ..           ...       ...           ...  ...       ...      ...        ...
# 95            71      9187             6  ...         0     2007     134000
# 96            34      3604             7  ...         0     2008     146000
# 97           140     11080             6  ...         0     2006     148000
# 98            60      7200             5  ...         0     2007     140000
# 99            58      9487             6  ...         0     2007     187000
#
# [100 rows x 31 columns]

# %%
del df['Screen Porch']

# %%
df
# Out:
#     Lot Frontage  Lot Area  Overall Qual  ...  Misc Val  Yr Sold  SalePrice
# 0             60      6756             5  ...         0     2008      78000
# 1             80     10000             5  ...         0     2007     215000
# 2             71      9353             4  ...         0     2006     116050
# 3             57      6420             5  ...         0     2006     123500
# 4             57      9245             5  ...         0     2008     145000
# ..           ...       ...           ...  ...       ...      ...        ...
# 95            71      9187             6  ...         0     2007     134000
# 96            34      3604             7  ...         0     2008     146000
# 97           140     11080             6  ...         0     2006     148000
# 98            60      7200             5  ...         0     2007     140000
# 99            58      9487             6  ...         0     2007     187000
#
# [100 rows x 30 columns]

# %%
df['Total SF'] = df['Total Bsmt SF'] + df['Enclosed Porch'] + df['Gr Liv Area'] + df['Wood Deck SF'] + df['Garage Area'] + df['Open Porch SF'] + df['Pool Area']

# %%
df
# Out:
#     Lot Frontage  Lot Area  Overall Qual  ...  Yr Sold  SalePrice  Total SF
# 0             60      6756             5  ...     2008      78000      1676
# 1             80     10000             5  ...     2007     215000      3700
# 2             71      9353             4  ...     2006     116050      2008
# 3             57      6420             5  ...     2006     123500      2436
# 4             57      9245             5  ...     2008     145000      2652
# ..           ...       ...           ...  ...      ...        ...       ...
# 95            71      9187             6  ...     2007     134000      2926
# 96            34      3604             7  ...     2008     146000      2723
# 97           140     11080             6  ...     2006     148000      2866
# 98            60      7200             5  ...     2007     140000      2593
# 99            58      9487             6  ...     2007     187000      3097
#
# [100 rows x 32 columns]

# %%
df['Total Full Bath'] = df['Bsmt Full Bath'] + df['Full Bath']

df['Total Half Bath'] = df['Bsmt Half Bath'] + df['Half Bath']

# %%
df
# Out:
#     Lot Frontage  Lot Area  ...  Total Full Bath  Total Half Bath
# 0             60      6756  ...                1                0
# 1             80     10000  ...                2                0
# 2             71      9353  ...                1                0
# 3             57      6420  ...                1                1
# 4             57      9245  ...                1                1
# ..           ...       ...  ...              ...              ...
# 95            71      9187  ...                1                1
# 96            34      3604  ...                2                0
# 97           140     11080  ...                3                0
# 98            60      7200  ...                2                0
# 99            58      9487  ...                3                1
#
# [100 rows x 34 columns]

# %%
del df['1st Flr SF']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '1st Flr SF'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-81-4a3a608f86dc> in <module>()
# ...

# %%
df
# Out:
#     Lot Frontage  Lot Area  ...  Total Full Bath  Total Half Bath
# 0             60      6756  ...                1                0
# 1             80     10000  ...                2                0
# 2             71      9353  ...                1                0
# 3             57      6420  ...                1                1
# 4             57      9245  ...                1                1
# ..           ...       ...  ...              ...              ...
# 95            71      9187  ...                1                1
# 96            34      3604  ...                2                0
# 97           140     11080  ...                3                0
# 98            60      7200  ...                2                0
# 99            58      9487  ...                3                1
#
# [100 rows x 33 columns]

# %%
del df['2nd Flr SF']

# %%
del df['Bedroom AbvGr']

# %%
del df['Bsmt Full Bath']

# %%
del df['Bsmt Half Bath']

# %%
del df['Bsmt Unf SF']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Bsmt Unf SF'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-8ea92de48f79> in <module>()
# ...

# %%
df
# Out:
#     Lot Frontage  Lot Area  ...  Total Full Bath  Total Half Bath
# 0             60      6756  ...                1                0
# 1             80     10000  ...                2                0
# 2             71      9353  ...                1                0
# 3             57      6420  ...                1                1
# 4             57      9245  ...                1                1
# ..           ...       ...  ...              ...              ...
# 95            71      9187  ...                1                1
# 96            34      3604  ...                2                0
# 97           140     11080  ...                3                0
# 98            60      7200  ...                2                0
# 99            58      9487  ...                3                1
#
# [100 rows x 28 columns]

# %%
del df['BsmtFin SF 2']

# %%
del df['Full Bath']

# %%
del df['Half Bath']

# %%
df
# Out:
#     Lot Frontage  Lot Area  ...  Total Full Bath  Total Half Bath
# 0             60      6756  ...                1                0
# 1             80     10000  ...                2                0
# 2             71      9353  ...                1                0
# 3             57      6420  ...                1                1
# 4             57      9245  ...                1                1
# ..           ...       ...  ...              ...              ...
# 95            71      9187  ...                1                1
# 96            34      3604  ...                2                0
# 97           140     11080  ...                3                0
# 98            60      7200  ...                2                0
# 99            58      9487  ...                3                1
#
# [100 rows x 25 columns]

# %%
def get_x_matrix(raw_data): 
  x_mat = raw_data.drop(columns=['SalePrice'])

  return x_mat

# %%
get_x_matrix(df)
# Out:
#     Lot Frontage  Lot Area  ...  Total Full Bath  Total Half Bath
# 0             60      6756  ...                1                0
# 1             80     10000  ...                2                0
# 2             71      9353  ...                1                0
# 3             57      6420  ...                1                1
# 4             57      9245  ...                1                1
# ..           ...       ...  ...              ...              ...
# 95            71      9187  ...                1                1
# 96            34      3604  ...                2                0
# 97           140     11080  ...                3                0
# 98            60      7200  ...                2                0
# 99            58      9487  ...                3                1
#
# [100 rows x 24 columns]

# %%
x = get_x_matrix(df)
y = df.SalePrice

# %%
model = LinearRegression().fit(x, y)

# %%
model.score(x, y)
# Out:
# 0.9027724170197832

# %%
model = Pipeline([
    ('poly', PolynomialFeatures(degree=2)),
    ('linreg', LinearRegression(fit_intercept=False))
])

model.fit(x, y)
# Out:
# Pipeline(memory=None,
#          steps=[('poly',
#                  PolynomialFeatures(degree=2, include_bias=True,
#                                     interaction_only=False, order='C')),
#                 ('linreg',
#                  LinearRegression(copy_X=True, fit_intercept=False, n_jobs=None,
#                                   normalize=False))],
#          verbose=False)

# %%
model.score(x, y)
# Out:
# 1.0

# %%
def mse(model, x, y):
    y_hat = model.predict(x)
    err = np.mean((y - y_hat)**2)

    return err

# %%
mse(model, x, y)
# Out:
# 4.5418682831592626e-15

# %%
kf = KFold(n_splits=10, shuffle=True)
res = cross_val_score(model, x, y, cv=kf, scoring=mse)

# %%
res

res.mean()
# Out:
# 59177936328.696

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
import numpy as np
import plotnine as pn
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from numpy.random import default_rng

import io
df = pd.read_csv(io.BytesIO(uploaded['housing_data.csv']))

df

#dropping variables that do not seem important to model SalePrice
del df['Street']
del df['Low Qual Fin SF']
del df['3Ssn Porch']
del df['Mo Sold']
del df['Year Built']
del df['Screen Porch']

#combining predictors to make better predictors 
df['Total SF'] = df['Total Bsmt SF'] + df['Enclosed Porch'] + df['Gr Liv Area'] + df['Wood Deck SF'] + df['Garage Area'] + df['Open Porch SF'] + df['Pool Area']
df['Total Full Bath'] = df['Bsmt Full Bath'] + df['Full Bath']
df['Total Half Bath'] = df['Bsmt Half Bath'] + df['Half Bath']

#deleting variables that are unecessary after making new predictors
del df['1st Flr SF']
del df['2nd Flr SF']
del df['Bedroom AbvGr']
del df['Bsmt Full Bath']
del df['Bsmt Half Bath']
del df['Bsmt Unf SF']
del df['BsmtFin SF 2']
del df['Full Bath']
del df['Half Bath']


def get_x_matrix(raw_data): 
  x_mat = raw_data.drop(columns=['SalePrice'])
#removing SalePrice column to get x variable matrix
  return x_mat


get_x_matrix(df)

x = get_x_matrix(df)
y = df.SalePrice

model = Pipeline([
    ('poly', PolynomialFeatures(degree=2)),
    ('linreg', LinearRegression(fit_intercept=False))
])

model.fit(x, y)
